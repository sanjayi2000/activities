# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\sanja\Downloads\archive (2)\teams.csv")

# %%
df
# Out:
#                    code                        team team_gender  \
# 0     ARCMTEAM3---CHN01  People's Republic of China           M
# 1     ARCMTEAM3---COL01                    Colombia           M
# 2     ARCMTEAM3---FRA01                      France           M
# 3     ARCMTEAM3---GBR01               Great Britain           M
# 4     ARCMTEAM3---IND01                       India           M
# ...                 ...                         ...         ...
# 1693  WPOWTEAM7---GRE01                      Greece           W
# 1694  WPOWTEAM7---HUN01                     Hungary           W
# 1695  WPOWTEAM7---ITA01                       Italy           W
# 1696  WPOWTEAM7---NED01                 Netherlands           W
# 1697  WPOWTEAM7---USA01    United States of America           W
#
#             country                country_full country_code  discipline  \
# 0             China  People's Republic of China          CHN     Archery
# ...

# %%
df=df.drop('code',axis=1)

# %%
country_distribution=df['country'].value_counts()

# %%
gender_distribution=df['team_gender'].value_counts()

# %%
 #Create a bar graph for countrywise distribution with reduced font size for country names
plt.figure(figsize=(12, 6))
bars = plt.bar(country_distribution.index, country_distribution.values)
plt.title('Countrywise Distribution of Players')
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.xticks(fontsize=6)  # Reduce font size of country names
plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.bar(gender_distribution.index, gender_distribution.values)
plt.title('Genderwise Distribution of Players')
plt.xlabel('Gender')
plt.ylabel('Number of Players')
plt.show()

# %%
print("Number of people from India:", df[df['country'] == 'India'].shape[0])
# Out:
# Number of people from India: 22

# %%
md=pd.read_csv(r"c:\Users\sanja\Downloads\archive (2)\medals.csv")

# %%
md
# Out:
#        medal_type  medal_code  medal_date                    name  \
# 0      Gold Medal           1  2024-07-27         Remco EVENEPOEL
# 1    Silver Medal           2  2024-07-27           Filippo GANNA
# 2    Bronze Medal           3  2024-07-27           Wout van AERT
# 3      Gold Medal           1  2024-07-27             Grace BROWN
# 4    Silver Medal           2  2024-07-27          Anna HENDERSON
# ..            ...         ...         ...                     ...
# 686  Bronze Medal           3  2024-08-07       Uzur DZHUZUPBEKOV
# 687    Gold Medal           1  2024-08-07   Sarah Ann HILDEBRANDT
# 688  Silver Medal           2  2024-08-07  Yusneylis GUZMAN LOPEZ
# 689  Bronze Medal           3  2024-08-07              SUSAKI Yui
# 690  Bronze Medal           3  2024-08-07               FENG Ziqi
#
#     country_code gender    discipline                          event  \
# 0            BEL      M  Cycling Road    Men's Individual Time Trial
# ...

# %%
medal_dist=md['medal_type'].value_counts()
medcountrydist=md['country_code'].value_counts()

# %%
merged_df = md.merge(df, on='country_code')

# Ensure data cleaning and consistency
merged_df = merged_df.dropna(subset=['country_code', 'medal_type'])  # Handle missing values
merged_df = merged_df.drop_duplicates()  # Remove duplicates

# Define a function to create subplots for each country
def plot_medals_by_country(data):
  countries = data['country'].unique()
  fig, axes = plt.subplots(nrows=len(countries), figsize=(10, len(countries)*3))

  for i, country in enumerate(countries):
    country_data = data[data['country'] == country]
    medal_counts = country_data['medal_type'].value_counts()
    medal_counts.plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'{country} Medals')
    axes[i].set_xlabel('Medal Type')
    axes[i].set_ylabel('Count')

  plt.tight_layout()
  plt.show()

# Call the function to create subplots
plot_medals_by_country(merged_df.copy())
